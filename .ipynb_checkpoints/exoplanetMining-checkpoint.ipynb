# %% [markdown]
# # Exoplanet Exploration through Data Mining
# ### Author: Josh Stanton
#
#  Date: February 09, 2025
#
#
# The NASA Exoplanet Archive file consists of 38,090 entries across 92 columns covering the planets'
# mass relative to Earth and Jupiter, Insolation Flux, the Orbital Periods, among other properties.
# In total, 38,090 rows by 92 columns results in just over 3.5 million points of data, which need to
# be cleaned and tailored to answer the questions:
#
# • Are there any patterns in exoplanet discovery over time?
#
# • Do certain facilities have a propensity for discovering certain exoplanet types more than others?
#
# • Is there a relationship between planet size and stellar gravity?
#
# • Does the number of stars relative to an exoplanet have any effect on its orbital?
#
# • Have specific discovery methods been more successful than others, or has a specific discovery method identified more planets than others?

# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
import prince
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, classification_report
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier


exoplanets = pd.read_csv('NASA Exoplanet Archive.csv')

# %%
exoplanets.columns
# Out:
# Index(['Planet Name', 'Host Name', 'Default Parameter Set', 'Number of Stars',
#        'Number of Planets', 'Discovery Method', 'Discovery Year',
#        'Discovery Facility', 'Solution Type', 'Controversial Flag',
#        'Planetary Parameter Reference', 'Orbital Period [days]',
#        'Orbital Period Upper Unc. [days]', 'Orbital Period Lower Unc. [days]',
#        'Orbital Period Limit Flag', 'Orbit Semi-Major Axis [au]',
#        'Orbit Semi-Major Axis Upper Unc. [au]',
#        'Orbit Semi-Major Axis Lower Unc. [au]',
#        'Orbit Semi-Major Axis Limit Flag', 'Planet Radius [Earth Radius]',
#        'Planet Radius Upper Unc. [Earth Radius]',
#        'Planet Radius Lower Unc. [Earth Radius]', 'Planet Radius Limit Flag',
#        'Planet Radius [Jupiter Radius]',
#        'Planet Radius Upper Unc. [Jupiter Radius]',
#        'Planet Radius Lower Unc. [Jupiter Radius]',
#        'Planet Radius Limit Flag.1', 'Planet Mass or Mass*sin(i) [Earth Mass]',
#        'Planet Mass or Mass*sin(i) [Earth Mass] Upper Unc.',
#        'Planet Mass or Mass*sin(i) [Earth Mass] Lower Unc.',
#        'Planet Mass or Mass*sin(i) [Earth Mass] Limit Flag',
#        'Planet Mass or Mass*sin(i) [Jupiter Mass]',
#        'Planet Mass or Mass*sin(i) [Jupiter Mass] Upper Unc.',
#        'Planet Mass or Mass*sin(i) [Jupiter Mass] Lower Unc.',
#        'Planet Mass or Mass*sin(i) [Jupiter Mass] Limit Flag',
#        'Planet Mass or Mass*sin(i) Provenance', 'Eccentricity',
#        'Eccentricity Upper Unc.', 'Eccentricity Lower Unc.',
#        'Eccentricity Limit Flag', 'Insolation Flux [Earth Flux]',
#        'Insolation Flux Upper Unc. [Earth Flux]',
#        'Insolation Flux Lower Unc. [Earth Flux]', 'Insolation Flux Limit Flag',
#        'Equilibrium Temperature [K]', 'Equilibrium Temperature Upper Unc. [K]',
#        'Equilibrium Temperature Lower Unc. [K]',
#        'Equilibrium Temperature Limit Flag',
#        'Data show Transit Timing Variations', 'Stellar Parameter Reference',
#        'Spectral Type', 'Stellar Effective Temperature [K]',
#        'Stellar Effective Temperature Upper Unc. [K]',
#        'Stellar Effective Temperature Lower Unc. [K]',
#        'Stellar Effective Temperature Limit Flag',
#        'Stellar Radius [Solar Radius]',
#        'Stellar Radius Upper Unc. [Solar Radius]',
#        'Stellar Radius Lower Unc. [Solar Radius]', 'Stellar Radius Limit Flag',
#        'Stellar Mass [Solar mass]', 'Stellar Mass Upper Unc [Solar mass]',
#        'Stellar Mass Lower Unc [Solar mass]', 'Stellar Mass Limit Flag',
#        'Stellar Metallicity [dex]', 'Stellar Metallicity Upper Unc. [dex]',
#        'Stellar Metallicity Lower Unc. [dex]',
#        'Stellar Metallicity Limit Flag', 'Stellar Metallicity Ratio',
#        'Stellar Surface Gravity [log10(cm/s**2)]',
#        'Stellar Surface Gravity Upper Unc. [log10(cm/s**2)]',
#        'Stellar Surface Gravity Lower Unc. [log10(cm/s**2)]',
#        'Stellar Surface Gravity Limit Flag', 'System Parameter Reference',
#        'RA [sexagesimal]', 'RA [deg]', 'Dec [sexagesimal]', 'Dec [deg]',
#        'Distance [pc]', 'Distance [pc] Upper Unc.', 'Distance [pc] Lower Unc.',
#        'V (Johnson) Magnitude', 'V (Johnson) Magnitude Upper Unc',
#        'V (Johnson) Magnitude Lower Unv', 'Ks (2MASS) Magnitude',
#        'Ks (2MASS) Magnitude Upper Unc', 'Ks (2MASS) Magnitude Lower Unc',
#        'Gaia Magnitude', 'Gaia Magnitude Upper Unc',
#        'Gaia Magnitude Lower Unc', 'Date of Last Update',
#        'Planetary Parameter Reference Publication Date', 'Release Date'],
#       dtype='object')

# %% [markdown]
# ## Unc. is shorthand for "uncertainty"

# %%
exoplanets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38090 entries, 0 to 38089
# Data columns (total 92 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Planet Name                                           38090 non-null  object
#  1   Host Name                                             38090 non-null  object
#  2   Default Parameter Set                                 38090 non-null  int64
#  3   Number of Stars                                       38090 non-null  int64
#  4   Number of Planets                                     38090 non-null  int64
#  5   Discovery Method                                      38090 non-null  object
#  6   Discovery Year                                        38090 non-null  int64
#  7   Discovery Facility                                    38090 non-null  object
#  8   Solution Type                                         38090 non-null  object
#  9   Controversial Flag                                    38090 non-null  int64
#  10  Planetary Parameter Reference                         38090 non-null  object
#  11  Orbital Period [days]                                 34904 non-null  float64
#  12  Orbital Period Upper Unc. [days]                      33362 non-null  float64
#  13  Orbital Period Lower Unc. [days]                      33361 non-null  float64
#  14  Orbital Period Limit Flag                             34904 non-null  float64
#  15  Orbit Semi-Major Axis [au]                            21538 non-null  float64
#  16  Orbit Semi-Major Axis Upper Unc. [au]                 7077 non-null   float64
#  17  Orbit Semi-Major Axis Lower Unc. [au]                 7076 non-null   float64
#  18  Orbit Semi-Major Axis Limit Flag                      24322 non-null  float64
#  19  Planet Radius [Earth Radius]                          26414 non-null  float64
#  20  Planet Radius Upper Unc. [Earth Radius]               25686 non-null  float64
#  21  Planet Radius Lower Unc. [Earth Radius]               25686 non-null  float64
#  22  Planet Radius Limit Flag                              29157 non-null  float64
#  23  Planet Radius [Jupiter Radius]                        26414 non-null  float64
#  24  Planet Radius Upper Unc. [Jupiter Radius]             25686 non-null  float64
#  25  Planet Radius Lower Unc. [Jupiter Radius]             25686 non-null  float64
#  26  Planet Radius Limit Flag.1                            26414 non-null  float64
#  27  Planet Mass or Mass*sin(i) [Earth Mass]               6331 non-null   float64
#  28  Planet Mass or Mass*sin(i) [Earth Mass] Upper Unc.    5803 non-null   float64
#  29  Planet Mass or Mass*sin(i) [Earth Mass] Lower Unc.    5803 non-null   float64
#  30  Planet Mass or Mass*sin(i) [Earth Mass] Limit Flag    6331 non-null   float64
#  31  Planet Mass or Mass*sin(i) [Jupiter Mass]             6330 non-null   float64
#  32  Planet Mass or Mass*sin(i) [Jupiter Mass] Upper Unc.  5797 non-null   float64
#  33  Planet Mass or Mass*sin(i) [Jupiter Mass] Lower Unc.  5797 non-null   float64
#  34  Planet Mass or Mass*sin(i) [Jupiter Mass] Limit Flag  6330 non-null   float64
#  35  Planet Mass or Mass*sin(i) Provenance                 6331 non-null   object
#  36  Eccentricity                                          18366 non-null  float64
#  37  Eccentricity Upper Unc.                               3503 non-null   float64
#  38  Eccentricity Lower Unc.                               3502 non-null   float64
#  39  Eccentricity Limit Flag                               21108 non-null  float64
#  40  Insolation Flux [Earth Flux]                          16732 non-null  float64
#  41  Insolation Flux Upper Unc. [Earth Flux]               15553 non-null  float64
#  42  Insolation Flux Lower Unc. [Earth Flux]               15553 non-null  float64
#  43  Insolation Flux Limit Flag                            21788 non-null  float64
#  44  Equilibrium Temperature [K]                           16681 non-null  float64
#  45  Equilibrium Temperature Upper Unc. [K]                2195 non-null   float64
#  46  Equilibrium Temperature Lower Unc. [K]                2195 non-null   float64
#  47  Equilibrium Temperature Limit Flag                    19422 non-null  float64
#  48  Data show Transit Timing Variations                   38090 non-null  int64
#  49  Stellar Parameter Reference                           37740 non-null  object
#  50  Spectral Type                                         2677 non-null   object
#  51  Stellar Effective Temperature [K]                     35096 non-null  float64
#  52  Stellar Effective Temperature Upper Unc. [K]          34339 non-null  float64
#  53  Stellar Effective Temperature Lower Unc. [K]          34032 non-null  float64
#  54  Stellar Effective Temperature Limit Flag              35096 non-null  float64
#  55  Stellar Radius [Solar Radius]                         35140 non-null  float64
#  56  Stellar Radius Upper Unc. [Solar Radius]              29610 non-null  float64
#  57  Stellar Radius Lower Unc. [Solar Radius]              29425 non-null  float64
#  58  Stellar Radius Limit Flag                             35140 non-null  float64
#  59  Stellar Mass [Solar mass]                             32322 non-null  float64
#  60  Stellar Mass Upper Unc [Solar mass]                   26908 non-null  float64
#  61  Stellar Mass Lower Unc [Solar mass]                   26713 non-null  float64
#  62  Stellar Mass Limit Flag                               32329 non-null  float64
#  63  Stellar Metallicity [dex]                             24293 non-null  float64
#  64  Stellar Metallicity Upper Unc. [dex]                  23622 non-null  float64
#  65  Stellar Metallicity Lower Unc. [dex]                  23622 non-null  float64
#  66  Stellar Metallicity Limit Flag                        26604 non-null  float64
#  67  Stellar Metallicity Ratio                             24096 non-null  object
#  68  Stellar Surface Gravity [log10(cm/s**2)]              29803 non-null  float64
#  69  Stellar Surface Gravity Upper Unc. [log10(cm/s**2)]   24521 non-null  float64
#  70  Stellar Surface Gravity Lower Unc. [log10(cm/s**2)]   24520 non-null  float64
#  71  Stellar Surface Gravity Limit Flag                    29803 non-null  float64
#  72  System Parameter Reference                            38090 non-null  object
#  73  RA [sexagesimal]                                      38090 non-null  object
#  74  RA [deg]                                              38090 non-null  float64
#  75  Dec [sexagesimal]                                     38090 non-null  object
#  76  Dec [deg]                                             38090 non-null  float64
#  77  Distance [pc]                                         37255 non-null  float64
#  78  Distance [pc] Upper Unc.                              36404 non-null  float64
#  79  Distance [pc] Lower Unc.                              36404 non-null  float64
#  80  V (Johnson) Magnitude                                 37362 non-null  float64
#  81  V (Johnson) Magnitude Upper Unc                       37349 non-null  float64
#  82  V (Johnson) Magnitude Lower Unv                       37348 non-null  float64
#  83  Ks (2MASS) Magnitude                                  37350 non-null  float64
#  84  Ks (2MASS) Magnitude Upper Unc                        37110 non-null  float64
#  85  Ks (2MASS) Magnitude Lower Unc                        37110 non-null  float64
#  86  Gaia Magnitude                                        37060 non-null  float64
#  87  Gaia Magnitude Upper Unc                              37060 non-null  float64
#  88  Gaia Magnitude Lower Unc                              37060 non-null  float64
#  89  Date of Last Update                                   38089 non-null  object
#  90  Planetary Parameter Reference Publication Date        38090 non-null  object
#  91  Release Date                                          38090 non-null  object
# dtypes: float64(70), int64(6), object(16)
# memory usage: 26.7+ MB

# %% [markdown]
# #  There is **a lot** of data, let's start with one question at a time.
# ### First, is there a relationship between planet size and stellar gravity?

# %%
gravity_size = exoplanets[['Planet Name','Planet Radius [Earth Radius]', 'Stellar Surface Gravity [log10(cm/s**2)]']]
gravity_size = gravity_size.dropna()
sns.heatmap(gravity_size.corr(method='pearson', numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### From a quick glance, there is very little correlation between the planet size and stellar gravity, so let's have a look at planet size and its orbital period.

# %%
orbital_size = exoplanets[['Planet Name','Planet Radius [Earth Radius]', 'Orbital Period [days]', 'Orbit Semi-Major Axis [au]']]
orbital_size = orbital_size.dropna()
sns.heatmap(orbital_size.corr(method='pearson', numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
discovery = exoplanets[['Planet Name', 'Host Name', 'Discovery Method', 'Discovery Year',
       'Discovery Facility', 'Solution Type']]
discovery.describe
# Out:
# <bound method NDFrame.describe of                 Planet Name           Host Name Discovery Method  \
# 0      11 Comae Berenices b  11 Comae Berenices  Radial Velocity
# 1      11 Comae Berenices b  11 Comae Berenices  Radial Velocity
# 2      11 Comae Berenices b  11 Comae Berenices  Radial Velocity
# 3        11 Ursae Minoris b    11 Ursae Minoris  Radial Velocity
# 4        11 Ursae Minoris b    11 Ursae Minoris  Radial Velocity
# ...                     ...                 ...              ...
# 38085      ups Andromedae d      ups Andromedae  Radial Velocity
# 38086          ups Leonis b          ups Leonis  Radial Velocity
# 38087          xi Aquilae b          xi Aquilae  Radial Velocity
# 38088          xi Aquilae b          xi Aquilae  Radial Velocity
# 38089          xi Aquilae b          xi Aquilae  Radial Velocity
#
#        Discovery Year                      Discovery Facility  \
# 0                2007                        Xinglong Station
# 1                2007                        Xinglong Station
# 2                2007                        Xinglong Station
# 3                2009  Thueringer Landessternwarte Tautenburg
# 4                2009  Thueringer Landessternwarte Tautenburg
# ...               ...                                     ...
# 38085            1999                  Multiple Observatories
# 38086            2021       Okayama Astrophysical Observatory
# 38087            2007       Okayama Astrophysical Observatory
# 38088            2007       Okayama Astrophysical Observatory
# 38089            2007       Okayama Astrophysical Observatory
#
#              Solution Type
# 0      Published Confirmed
# 1      Published Confirmed
# 2      Published Confirmed
# 3      Published Confirmed
# 4      Published Confirmed
# ...                    ...
# 38085  Published Confirmed
# 38086  Published Confirmed
# 38087  Published Confirmed
# 38088  Published Confirmed
# 38089  Published Confirmed
#
# [38090 rows x 6 columns]>

# %%
count = discovery.groupby('Discovery Year').size()

# %%
discovery['Discovery Method'].unique()
# Out:
# array(['Radial Velocity', 'Imaging', 'Eclipse Timing Variations',
#        'Transit', 'Transit Timing Variations', 'Astrometry',
#        'Microlensing', 'Disk Kinematics', 'Orbital Brightness Modulation',
#        'Pulsation Timing Variations', 'Pulsar Timing'], dtype=object)

# %%
exoplanets.groupby('Discovery Method').size().sort_values(ascending=False)
# Out:
# Discovery Method
# Transit                          34445
# Radial Velocity                   2584
# Microlensing                       697
# Transit Timing Variations          152
# Imaging                            148
# Eclipse Timing Variations           24
# Orbital Brightness Modulation       21
# Pulsar Timing                       13
# Astrometry                           3
# Pulsation Timing Variations          2
# Disk Kinematics                      1
# dtype: int64

# %%
exoplanet_gravity = exoplanets[['Planet Name', 'Host Name','Planet Radius [Earth Radius]','Planet Mass or Mass*sin(i) [Earth Mass]']]

sns.heatmap(exoplanet_gravity.corr(method='pearson', numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
exoplanet_sizes = exoplanets[['Planet Name', 'Host Name', 'Orbital Period [days]', 'Planet Radius [Earth Radius]',
                              'Orbit Semi-Major Axis [au]','Planet Radius [Jupiter Radius]','Planet Mass or Mass*sin(i) [Earth Mass]']]

exoplanet_sizes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38090 entries, 0 to 38089
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Planet Name                              38090 non-null  object
#  1   Host Name                                38090 non-null  object
#  2   Orbital Period [days]                    34904 non-null  float64
#  3   Planet Radius [Earth Radius]             26414 non-null  float64
#  4   Orbit Semi-Major Axis [au]               21538 non-null  float64
#  5   Planet Radius [Jupiter Radius]           26414 non-null  float64
#  6   Planet Mass or Mass*sin(i) [Earth Mass]  6331 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 2.0+ MB

# %%
sns.heatmap(exoplanet_sizes.corr(method='pearson', numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Let's instead take a look at the Discovery Facilities themselves.

# %%
exoplanets['Discovery Facility'].unique()
# Out:
# array(['Xinglong Station', 'Thueringer Landessternwarte Tautenburg',
#        'Okayama Astrophysical Observatory', 'W. M. Keck Observatory',
#        'Multiple Observatories', 'Lick Observatory', 'Gemini Observatory',
#        'Subaru Telescope', 'Paranal Observatory',
#        'Cerro Tololo Inter-American Observatory', 'Mauna Kea Observatory',
#        'European Space Agency (ESA) Gaia Satellite',
#        'Hubble Space Telescope', 'Kepler', 'Haute-Provence Observatory',
#        'McDonald Observatory', 'Anglo-Australian Telescope',
#        'Bohyunsan Optical Astronomical Observatory',
#        'Transiting Exoplanet Survey Satellite (TESS)',
#        'Roque de los Muchachos Observatory', 'K2',
#        'Wide-field Infrared Survey Explorer (WISE) Sat',
#        'La Silla Observatory', 'Calar Alto Observatory',
#        'NASA Infrared Telescope Facility (IRTF)', 'CoRoT',
#        'Multiple Facilities', 'Yunnan Astronomical Observatory',
#        'Spitzer Space Telescope', 'MEarth Project',
#        'Very Long Baseline Array', 'Acton Sky Portal Observatory',
#        'Palomar Observatory', 'HATNet', 'HATSouth',
#        'Kitt Peak National Observatory', 'Las Campanas Observatory',
#        'CHaracterising ExOPlanets Satellite (CHEOPS)',
#        'European Southern Observatory',
#        'Fred Lawrence Whipple Observatory', 'Apache Point Observatory',
#        'Atacama Large Millimeter Array (ALMA)', 'KELT', 'KELT-South',
#        'KELT-North', 'KMTNet', 'KOINet', 'SPECULOOS Southern Observatory',
#        'Large Binocular Telescope Observatory',
#        'South African Radio Astronomy Observatory (SAR', 'MOA',
#        'Next-Generation Transit Survey (NGTS)', 'Winer Observatory',
#        'OGLE', 'Arecibo Observatory', 'Parkes Observatory', 'Qatar',
#        'Leoncito Astronomical Complex', 'Infrared Survey Facility',
#        'TrES', 'Teide Observatory', 'SuperWASP', 'SuperWASP-South',
#        'SuperWASP-North', 'WASP-South',
#        'James Webb Space Telescope (JWST)',
#        'United Kingdom Infrared Telescope', 'Haleakala Observatory', 'XO',
#        'Lowell Observatory',
#        'University of Canterbury Mt John Observatory'], dtype=object)

# %%
count = exoplanets.groupby('Discovery Facility').size()
count = count.sort_values(ascending=False)

print(count)
# Out:
# Discovery Facility
# Kepler                                            28217
# K2                                                 2017
# Transiting Exoplanet Survey Satellite (TESS)       1581
# SuperWASP                                           964
# W. M. Keck Observatory                              648
#                                                   ...
# Wide-field Infrared Survey Explorer (WISE) Sat        1
# Winer Observatory                                     1
# Apache Point Observatory                              1
# Leoncito Astronomical Complex                         1
# Teide Observatory                                     1
# Length: 71, dtype: int64

# %%
count = exoplanets.groupby('Discovery Method').size()
count = count.sort_values(ascending=False)

print(count)
# Out:
# Discovery Method
# Transit                          34445
# Radial Velocity                   2584
# Microlensing                       697
# Transit Timing Variations          152
# Imaging                            148
# Eclipse Timing Variations           24
# Orbital Brightness Modulation       21
# Pulsar Timing                       13
# Astrometry                           3
# Pulsation Timing Variations          2
# Disk Kinematics                      1
# dtype: int64

# %%
count = exoplanets.groupby('Discovery Year').size()
#count = count.sort_values(ascending=False)

print(count)
# Out:
# Discovery Year
# 1992        6
# 1994        2
# 1995        5
# 1996       41
# 1997        4
# 1998       39
# 1999       80
# 2000       78
# 2001       58
# 2002      144
# 2003       87
# 2004      173
# 2005      161
# 2006      149
# 2007      323
# 2008      332
# 2009      427
# 2010      615
# 2011     1072
# 2012     1150
# 2013     1074
# 2014     9644
# 2015      935
# 2016    13295
# 2017      579
# 2018      963
# 2019      545
# 2020      918
# 2021     2859
# 2022      776
# 2023     1031
# 2024      511
# 2025       14
# dtype: int64

# %%
orbital_size.describe()
# Out:
#        Planet Radius [Earth Radius]  Orbital Period [days]  \
# count                  18383.000000           1.838300e+04
# mean                       5.998098           2.297949e+04
# std                       87.087893           2.966155e+06
# min                        0.270000           1.797150e-01
# 25%                        1.510000           4.417694e+00
# 50%                        2.220000           1.000653e+01
# 75%                        3.120000           2.309266e+01
# max                     4282.980000           4.020000e+08
#
#        Orbit Semi-Major Axis [au]
# count                18383.000000
# mean                     0.600061
# std                     55.502574
# min                      0.005800
# 25%                      0.051400
# 50%                      0.087800
# 75%                      0.156175
# max                   7506.000000

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
# Let's add an encoding to the discovery facility so it can be used as a metric
exoplanets['Discovery Facility Encoded'] = encoder.fit_transform(exoplanets['Discovery Facility'])
exoplanets['Discovery Method Encoded'] = encoder.fit_transform(exoplanets['Discovery Method'])

print(exoplanets['Discovery Method'].unique(), '\n', exoplanets['Discovery Method Encoded'].unique())
# Out:
# ['Radial Velocity' 'Imaging' 'Eclipse Timing Variations' 'Transit'
#  'Transit Timing Variations' 'Astrometry' 'Microlensing' 'Disk Kinematics'
#  'Orbital Brightness Modulation' 'Pulsation Timing Variations'
#  'Pulsar Timing']
#  [ 8  3  2  9 10  0  4  1  5  7  6]

# %% [markdown]
# ### Let's now consider the different factors of discoveries over time with respect to different facilities and see what we are able to find.

# %%
facility_finds = exoplanets[['Discovery Facility','Discovery Facility Encoded', 'Orbital Period [days]', 'Planet Radius [Earth Radius]',
                              'Orbit Semi-Major Axis [au]', 'Planet Mass or Mass*sin(i) [Earth Mass]', 
                             'Discovery Method', 'Discovery Method Encoded', 'Discovery Year']]

sns.heatmap(facility_finds.corr(method='pearson', numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # There does not appear to be a means of a binary solution to this data, so let's instead investigate k-means clustering and see what clusters it generates.

# %%
X = facility_finds
sns.relplot(x='Planet Mass or Mass*sin(i) [Earth Mass]', y='Planet Radius [Earth Radius]', data=X, height=10, hue='Discovery Facility');

# %%
sns.relplot(x='Planet Mass or Mass*sin(i) [Earth Mass]', y='Planet Radius [Earth Radius]', data=X, height=10, hue='Discovery Method');

# %%
sns.relplot(x='Discovery Facility Encoded', y='Discovery Method', data=X, height=10, hue='Discovery Year');

# %%
Xarray = exoplanets[['Discovery Facility Encoded', 'Orbital Period [days]', 'Planet Radius [Earth Radius]',
                               'Discovery Method Encoded', 'Discovery Year']]
Xarray = Xarray.dropna()
vals = Xarray.values
print(vals)
# Out:
# [[3.800000e+01 7.370000e-01 1.897000e+00 8.000000e+00 2.004000e+03]
#  [3.800000e+01 7.365474e-01 1.875000e+00 8.000000e+00 2.004000e+03]
#  [3.800000e+01 7.365390e-01 1.910000e+00 8.000000e+00 2.004000e+03]
#  ...
#  [6.000000e+01 6.267900e+00 2.042000e+00 9.000000e+00 2.018000e+03]
#  [6.000000e+01 6.268340e+00 2.060000e+00 9.000000e+00 2.018000e+03]
#  [6.000000e+01 6.267832e+00 1.998000e+00 9.000000e+00 2.018000e+03]]

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import scale

kmodel = KMeans(n_clusters=8, random_state=42)

kmodel = kmodel.fit(scale(Xarray))

# %%
plt.figure(figsize=(20, 20))
plt.scatter(Xarray['Discovery Facility Encoded'], Xarray['Planet Radius [Earth Radius]'], c=kmodel.labels_.astype(float))
plt.show()

# %%
wss = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(Xarray)
    wss.append(kmeans.inertia_)

plt.figure(figsize=(10, 5))
plt.plot(range(1, 11), wss, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('Within-Cluster Sum of Squares')
plt.show()

# %%
from sklearn.metrics import silhouette_score

silhouette = []
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k)
    cluster_labels = kmeans.fit_predict(Xarray)
    silhouette_avg = silhouette_score(Xarray, cluster_labels)
    silhouette.append(silhouette_avg)

plt.figure(figsize=(10, 5))
plt.plot(range(2, 11), silhouette, marker='o')
plt.title('Silhouette Method')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %% [markdown]
# ###  So, there are difficulties in finding patterns looking at the broad spectrum, so let's try looking at specific Discovery Facilities

# %%
kepler = exoplanets.loc[exoplanets['Discovery Facility'] == 'Kepler']

# %%
kepler.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28217 entries, 47 to 35075
# Data columns (total 94 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Planet Name                                           28217 non-null  object
#  1   Host Name                                             28217 non-null  object
#  2   Default Parameter Set                                 28217 non-null  int64
#  3   Number of Stars                                       28217 non-null  int64
#  4   Number of Planets                                     28217 non-null  int64
#  5   Discovery Method                                      28217 non-null  object
#  6   Discovery Year                                        28217 non-null  int64
#  7   Discovery Facility                                    28217 non-null  object
#  8   Solution Type                                         28217 non-null  object
#  9   Controversial Flag                                    28217 non-null  int64
#  10  Planetary Parameter Reference                         28217 non-null  object
#  11  Orbital Period [days]                                 26003 non-null  float64
#  12  Orbital Period Upper Unc. [days]                      24953 non-null  float64
#  13  Orbital Period Lower Unc. [days]                      24953 non-null  float64
#  14  Orbital Period Limit Flag                             26003 non-null  float64
#  15  Orbit Semi-Major Axis [au]                            15877 non-null  float64
#  16  Orbit Semi-Major Axis Upper Unc. [au]                 1848 non-null   float64
#  17  Orbit Semi-Major Axis Lower Unc. [au]                 1848 non-null   float64
#  18  Orbit Semi-Major Axis Limit Flag                      18624 non-null  float64
#  19  Planet Radius [Earth Radius]                          21461 non-null  float64
#  20  Planet Radius Upper Unc. [Earth Radius]               20938 non-null  float64
#  21  Planet Radius Lower Unc. [Earth Radius]               20938 non-null  float64
#  22  Planet Radius Limit Flag                              24201 non-null  float64
#  23  Planet Radius [Jupiter Radius]                        21461 non-null  float64
#  24  Planet Radius Upper Unc. [Jupiter Radius]             20938 non-null  float64
#  25  Planet Radius Lower Unc. [Jupiter Radius]             20938 non-null  float64
#  26  Planet Radius Limit Flag.1                            21461 non-null  float64
#  27  Planet Mass or Mass*sin(i) [Earth Mass]               847 non-null    float64
#  28  Planet Mass or Mass*sin(i) [Earth Mass] Upper Unc.    739 non-null    float64
#  29  Planet Mass or Mass*sin(i) [Earth Mass] Lower Unc.    739 non-null    float64
#  30  Planet Mass or Mass*sin(i) [Earth Mass] Limit Flag    847 non-null    float64
#  31  Planet Mass or Mass*sin(i) [Jupiter Mass]             847 non-null    float64
#  32  Planet Mass or Mass*sin(i) [Jupiter Mass] Upper Unc.  739 non-null    float64
#  33  Planet Mass or Mass*sin(i) [Jupiter Mass] Lower Unc.  739 non-null    float64
#  34  Planet Mass or Mass*sin(i) [Jupiter Mass] Limit Flag  847 non-null    float64
#  35  Planet Mass or Mass*sin(i) Provenance                 847 non-null    object
#  36  Eccentricity                                          13726 non-null  float64
#  37  Eccentricity Upper Unc.                               295 non-null    float64
#  38  Eccentricity Lower Unc.                               295 non-null    float64
#  39  Eccentricity Limit Flag                               16464 non-null  float64
#  40  Insolation Flux [Earth Flux]                          14692 non-null  float64
#  41  Insolation Flux Upper Unc. [Earth Flux]               14610 non-null  float64
#  42  Insolation Flux Lower Unc. [Earth Flux]               14610 non-null  float64
#  43  Insolation Flux Limit Flag                            19742 non-null  float64
#  44  Equilibrium Temperature [K]                           13495 non-null  float64
#  45  Equilibrium Temperature Upper Unc. [K]                215 non-null    float64
#  46  Equilibrium Temperature Lower Unc. [K]                215 non-null    float64
#  47  Equilibrium Temperature Limit Flag                    16233 non-null  float64
#  48  Data show Transit Timing Variations                   28217 non-null  int64
#  49  Stellar Parameter Reference                           28215 non-null  object
#  50  Spectral Type                                         182 non-null    object
#  51  Stellar Effective Temperature [K]                     27532 non-null  float64
#  52  Stellar Effective Temperature Upper Unc. [K]          27412 non-null  float64
#  53  Stellar Effective Temperature Lower Unc. [K]          27325 non-null  float64
#  54  Stellar Effective Temperature Limit Flag              27532 non-null  float64
#  55  Stellar Radius [Solar Radius]                         27606 non-null  float64
#  56  Stellar Radius Upper Unc. [Solar Radius]              22548 non-null  float64
#  57  Stellar Radius Lower Unc. [Solar Radius]              22547 non-null  float64
#  58  Stellar Radius Limit Flag                             27606 non-null  float64
#  59  Stellar Mass [Solar mass]                             24799 non-null  float64
#  60  Stellar Mass Upper Unc [Solar mass]                   19867 non-null  float64
#  61  Stellar Mass Lower Unc [Solar mass]                   19866 non-null  float64
#  62  Stellar Mass Limit Flag                               24806 non-null  float64
#  63  Stellar Metallicity [dex]                             18855 non-null  float64
#  64  Stellar Metallicity Upper Unc. [dex]                  18813 non-null  float64
#  65  Stellar Metallicity Lower Unc. [dex]                  18813 non-null  float64
#  66  Stellar Metallicity Limit Flag                        21163 non-null  float64
#  67  Stellar Metallicity Ratio                             18828 non-null  object
#  68  Stellar Surface Gravity [log10(cm/s**2)]              23424 non-null  float64
#  69  Stellar Surface Gravity Upper Unc. [log10(cm/s**2)]   18628 non-null  float64
#  70  Stellar Surface Gravity Lower Unc. [log10(cm/s**2)]   18628 non-null  float64
#  71  Stellar Surface Gravity Limit Flag                    23424 non-null  float64
#  72  System Parameter Reference                            28217 non-null  object
#  73  RA [sexagesimal]                                      28217 non-null  object
#  74  RA [deg]                                              28217 non-null  float64
#  75  Dec [sexagesimal]                                     28217 non-null  object
#  76  Dec [deg]                                             28217 non-null  float64
#  77  Distance [pc]                                         27522 non-null  float64
#  78  Distance [pc] Upper Unc.                              26732 non-null  float64
#  79  Distance [pc] Lower Unc.                              26732 non-null  float64
#  80  V (Johnson) Magnitude                                 28217 non-null  float64
#  81  V (Johnson) Magnitude Upper Unc                       28217 non-null  float64
#  82  V (Johnson) Magnitude Lower Unv                       28217 non-null  float64
#  83  Ks (2MASS) Magnitude                                  28217 non-null  float64
#  84  Ks (2MASS) Magnitude Upper Unc                        27998 non-null  float64
#  85  Ks (2MASS) Magnitude Lower Unc                        27998 non-null  float64
#  86  Gaia Magnitude                                        27951 non-null  float64
#  87  Gaia Magnitude Upper Unc                              27951 non-null  float64
#  88  Gaia Magnitude Lower Unc                              27951 non-null  float64
#  89  Date of Last Update                                   28217 non-null  object
#  90  Planetary Parameter Reference Publication Date        28217 non-null  object
#  91  Release Date                                          28217 non-null  object
#  92  Discovery Facility Encoded                            28217 non-null  int32
#  93  Discovery Method Encoded                              28217 non-null  int32
# dtypes: float64(70), int32(2), int64(6), object(16)
# memory usage: 20.2+ MB

# %%
k_two = exoplanets.loc[exoplanets['Discovery Facility'] == 'K2']

# %%
k_two.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2017 entries, 191 to 37873
# Data columns (total 94 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Planet Name                                           2017 non-null   object
#  1   Host Name                                             2017 non-null   object
#  2   Default Parameter Set                                 2017 non-null   int64
#  3   Number of Stars                                       2017 non-null   int64
#  4   Number of Planets                                     2017 non-null   int64
#  5   Discovery Method                                      2017 non-null   object
#  6   Discovery Year                                        2017 non-null   int64
#  7   Discovery Facility                                    2017 non-null   object
#  8   Solution Type                                         2017 non-null   object
#  9   Controversial Flag                                    2017 non-null   int64
#  10  Planetary Parameter Reference                         2017 non-null   object
#  11  Orbital Period [days]                                 2009 non-null   float64
#  12  Orbital Period Upper Unc. [days]                      1710 non-null   float64
#  13  Orbital Period Lower Unc. [days]                      1710 non-null   float64
#  14  Orbital Period Limit Flag                             2009 non-null   float64
#  15  Orbit Semi-Major Axis [au]                            679 non-null    float64
#  16  Orbit Semi-Major Axis Upper Unc. [au]                 677 non-null    float64
#  17  Orbit Semi-Major Axis Lower Unc. [au]                 677 non-null    float64
#  18  Orbit Semi-Major Axis Limit Flag                      679 non-null    float64
#  19  Planet Radius [Earth Radius]                          1759 non-null   float64
#  20  Planet Radius Upper Unc. [Earth Radius]               1626 non-null   float64
#  21  Planet Radius Lower Unc. [Earth Radius]               1626 non-null   float64
#  22  Planet Radius Limit Flag                              1759 non-null   float64
#  23  Planet Radius [Jupiter Radius]                        1759 non-null   float64
#  24  Planet Radius Upper Unc. [Jupiter Radius]             1626 non-null   float64
#  25  Planet Radius Lower Unc. [Jupiter Radius]             1626 non-null   float64
#  26  Planet Radius Limit Flag.1                            1759 non-null   float64
#  27  Planet Mass or Mass*sin(i) [Earth Mass]               273 non-null    float64
#  28  Planet Mass or Mass*sin(i) [Earth Mass] Upper Unc.    234 non-null    float64
#  29  Planet Mass or Mass*sin(i) [Earth Mass] Lower Unc.    234 non-null    float64
#  30  Planet Mass or Mass*sin(i) [Earth Mass] Limit Flag    273 non-null    float64
#  31  Planet Mass or Mass*sin(i) [Jupiter Mass]             273 non-null    float64
#  32  Planet Mass or Mass*sin(i) [Jupiter Mass] Upper Unc.  234 non-null    float64
#  33  Planet Mass or Mass*sin(i) [Jupiter Mass] Lower Unc.  234 non-null    float64
#  34  Planet Mass or Mass*sin(i) [Jupiter Mass] Limit Flag  273 non-null    float64
#  35  Planet Mass or Mass*sin(i) Provenance                 273 non-null    object
#  36  Eccentricity                                          345 non-null    float64
#  37  Eccentricity Upper Unc.                               195 non-null    float64
#  38  Eccentricity Lower Unc.                               195 non-null    float64
#  39  Eccentricity Limit Flag                               346 non-null    float64
#  40  Insolation Flux [Earth Flux]                          423 non-null    float64
#  41  Insolation Flux Upper Unc. [Earth Flux]               327 non-null    float64
#  42  Insolation Flux Lower Unc. [Earth Flux]               327 non-null    float64
#  43  Insolation Flux Limit Flag                            423 non-null    float64
#  44  Equilibrium Temperature [K]                           593 non-null    float64
#  45  Equilibrium Temperature Upper Unc. [K]                496 non-null    float64
#  46  Equilibrium Temperature Lower Unc. [K]                496 non-null    float64
#  47  Equilibrium Temperature Limit Flag                    593 non-null    float64
#  48  Data show Transit Timing Variations                   2017 non-null   int64
#  49  Stellar Parameter Reference                           2014 non-null   object
#  50  Spectral Type                                         254 non-null    object
#  51  Stellar Effective Temperature [K]                     1587 non-null   float64
#  52  Stellar Effective Temperature Upper Unc. [K]          1474 non-null   float64
#  53  Stellar Effective Temperature Lower Unc. [K]          1474 non-null   float64
#  54  Stellar Effective Temperature Limit Flag              1587 non-null   float64
#  55  Stellar Radius [Solar Radius]                         1981 non-null   float64
#  56  Stellar Radius Upper Unc. [Solar Radius]              1756 non-null   float64
#  57  Stellar Radius Lower Unc. [Solar Radius]              1756 non-null   float64
#  58  Stellar Radius Limit Flag                             1981 non-null   float64
#  59  Stellar Mass [Solar mass]                             1319 non-null   float64
#  60  Stellar Mass Upper Unc [Solar mass]                   1293 non-null   float64
#  61  Stellar Mass Lower Unc [Solar mass]                   1293 non-null   float64
#  62  Stellar Mass Limit Flag                               1319 non-null   float64
#  63  Stellar Metallicity [dex]                             1053 non-null   float64
#  64  Stellar Metallicity Upper Unc. [dex]                  1043 non-null   float64
#  65  Stellar Metallicity Lower Unc. [dex]                  1043 non-null   float64
#  66  Stellar Metallicity Limit Flag                        1053 non-null   float64
#  67  Stellar Metallicity Ratio                             1053 non-null   object
#  68  Stellar Surface Gravity [log10(cm/s**2)]              1321 non-null   float64
#  69  Stellar Surface Gravity Upper Unc. [log10(cm/s**2)]   1277 non-null   float64
#  70  Stellar Surface Gravity Lower Unc. [log10(cm/s**2)]   1277 non-null   float64
#  71  Stellar Surface Gravity Limit Flag                    1321 non-null   float64
#  72  System Parameter Reference                            2017 non-null   object
#  73  RA [sexagesimal]                                      2017 non-null   object
#  74  RA [deg]                                              2017 non-null   float64
#  75  Dec [sexagesimal]                                     2017 non-null   object
#  76  Dec [deg]                                             2017 non-null   float64
#  77  Distance [pc]                                         2010 non-null   float64
#  78  Distance [pc] Upper Unc.                              2005 non-null   float64
#  79  Distance [pc] Lower Unc.                              2005 non-null   float64
#  80  V (Johnson) Magnitude                                 2010 non-null   float64
#  81  V (Johnson) Magnitude Upper Unc                       2010 non-null   float64
#  82  V (Johnson) Magnitude Lower Unv                       2010 non-null   float64
#  83  Ks (2MASS) Magnitude                                  2008 non-null   float64
#  84  Ks (2MASS) Magnitude Upper Unc                        2008 non-null   float64
#  85  Ks (2MASS) Magnitude Lower Unc                        2008 non-null   float64
#  86  Gaia Magnitude                                        2009 non-null   float64
#  87  Gaia Magnitude Upper Unc                              2009 non-null   float64
#  88  Gaia Magnitude Lower Unc                              2009 non-null   float64
#  89  Date of Last Update                                   2017 non-null   object
#  90  Planetary Parameter Reference Publication Date        2017 non-null   object
#  91  Release Date                                          2017 non-null   object
#  92  Discovery Facility Encoded                            2017 non-null   int32
#  93  Discovery Method Encoded                              2017 non-null   int32
# dtypes: float64(70), int32(2), int64(6), object(16)
# memory usage: 1.4+ MB

# %%
columns_to_keep = [col for col in kepler.columns if 'unc' not in col.lower()]
columns_to_keep = [col for col in columns_to_keep if 'flag' not in col.lower()]
columns_to_keep = [col for col in columns_to_keep if 'reference' not in col.lower()]
columns_to_keep = [col for col in columns_to_keep if 'lower' not in col.lower()]
kepler_filtered = kepler[columns_to_keep]
k_two_filtered = k_two[columns_to_keep]

# %%
kepler_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28217 entries, 47 to 35075
# Data columns (total 39 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Planet Name                                28217 non-null  object
#  1   Host Name                                  28217 non-null  object
#  2   Default Parameter Set                      28217 non-null  int64
#  3   Number of Stars                            28217 non-null  int64
#  4   Number of Planets                          28217 non-null  int64
#  5   Discovery Method                           28217 non-null  object
#  6   Discovery Year                             28217 non-null  int64
#  7   Discovery Facility                         28217 non-null  object
#  8   Solution Type                              28217 non-null  object
#  9   Orbital Period [days]                      26003 non-null  float64
#  10  Orbit Semi-Major Axis [au]                 15877 non-null  float64
#  11  Planet Radius [Earth Radius]               21461 non-null  float64
#  12  Planet Radius [Jupiter Radius]             21461 non-null  float64
#  13  Planet Mass or Mass*sin(i) [Earth Mass]    847 non-null    float64
#  14  Planet Mass or Mass*sin(i) [Jupiter Mass]  847 non-null    float64
#  15  Planet Mass or Mass*sin(i) Provenance      847 non-null    object
#  16  Eccentricity                               13726 non-null  float64
#  17  Insolation Flux [Earth Flux]               14692 non-null  float64
#  18  Equilibrium Temperature [K]                13495 non-null  float64
#  19  Data show Transit Timing Variations        28217 non-null  int64
#  20  Spectral Type                              182 non-null    object
#  21  Stellar Effective Temperature [K]          27532 non-null  float64
#  22  Stellar Radius [Solar Radius]              27606 non-null  float64
#  23  Stellar Mass [Solar mass]                  24799 non-null  float64
#  24  Stellar Metallicity [dex]                  18855 non-null  float64
#  25  Stellar Metallicity Ratio                  18828 non-null  object
#  26  Stellar Surface Gravity [log10(cm/s**2)]   23424 non-null  float64
#  27  RA [sexagesimal]                           28217 non-null  object
#  28  RA [deg]                                   28217 non-null  float64
#  29  Dec [sexagesimal]                          28217 non-null  object
#  30  Dec [deg]                                  28217 non-null  float64
#  31  Distance [pc]                              27522 non-null  float64
#  32  V (Johnson) Magnitude                      28217 non-null  float64
#  33  Ks (2MASS) Magnitude                       28217 non-null  float64
#  34  Gaia Magnitude                             27951 non-null  float64
#  35  Date of Last Update                        28217 non-null  object
#  36  Release Date                               28217 non-null  object
#  37  Discovery Facility Encoded                 28217 non-null  int32
#  38  Discovery Method Encoded                   28217 non-null  int32
# dtypes: float64(20), int32(2), int64(5), object(12)
# memory usage: 8.4+ MB

# %%
k_two_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2017 entries, 191 to 37873
# Data columns (total 39 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Planet Name                                2017 non-null   object
#  1   Host Name                                  2017 non-null   object
#  2   Default Parameter Set                      2017 non-null   int64
#  3   Number of Stars                            2017 non-null   int64
#  4   Number of Planets                          2017 non-null   int64
#  5   Discovery Method                           2017 non-null   object
#  6   Discovery Year                             2017 non-null   int64
#  7   Discovery Facility                         2017 non-null   object
#  8   Solution Type                              2017 non-null   object
#  9   Orbital Period [days]                      2009 non-null   float64
#  10  Orbit Semi-Major Axis [au]                 679 non-null    float64
#  11  Planet Radius [Earth Radius]               1759 non-null   float64
#  12  Planet Radius [Jupiter Radius]             1759 non-null   float64
#  13  Planet Mass or Mass*sin(i) [Earth Mass]    273 non-null    float64
#  14  Planet Mass or Mass*sin(i) [Jupiter Mass]  273 non-null    float64
#  15  Planet Mass or Mass*sin(i) Provenance      273 non-null    object
#  16  Eccentricity                               345 non-null    float64
#  17  Insolation Flux [Earth Flux]               423 non-null    float64
#  18  Equilibrium Temperature [K]                593 non-null    float64
#  19  Data show Transit Timing Variations        2017 non-null   int64
#  20  Spectral Type                              254 non-null    object
#  21  Stellar Effective Temperature [K]          1587 non-null   float64
#  22  Stellar Radius [Solar Radius]              1981 non-null   float64
#  23  Stellar Mass [Solar mass]                  1319 non-null   float64
#  24  Stellar Metallicity [dex]                  1053 non-null   float64
#  25  Stellar Metallicity Ratio                  1053 non-null   object
#  26  Stellar Surface Gravity [log10(cm/s**2)]   1321 non-null   float64
#  27  RA [sexagesimal]                           2017 non-null   object
#  28  RA [deg]                                   2017 non-null   float64
#  29  Dec [sexagesimal]                          2017 non-null   object
#  30  Dec [deg]                                  2017 non-null   float64
#  31  Distance [pc]                              2010 non-null   float64
#  32  V (Johnson) Magnitude                      2010 non-null   float64
#  33  Ks (2MASS) Magnitude                       2008 non-null   float64
#  34  Gaia Magnitude                             2009 non-null   float64
#  35  Date of Last Update                        2017 non-null   object
#  36  Release Date                               2017 non-null   object
#  37  Discovery Facility Encoded                 2017 non-null   int32
#  38  Discovery Method Encoded                   2017 non-null   int32
# dtypes: float64(20), int32(2), int64(5), object(12)
# memory usage: 614.6+ KB

# %%
kepler_filtered['Spectral Type']
# Out:
# 47       NaN
# 48       NaN
# 5863     NaN
# 5864     NaN
# 5865     NaN
#         ...
# 35071    NaN
# 35072    NaN
# 35073    NaN
# 35074    NaN
# 35075    NaN
# Name: Spectral Type, Length: 28217, dtype: object

# %%
kepler_discovery = kepler_filtered[['Planet Name', 'Host Name', 'Number of Stars', 'Number of Planets', 'Discovery Method', 
                                   'Discovery Year', 'Discovery Method Encoded', 'Orbital Period [days]',
                                   'Insolation Flux [Earth Flux]', 'Gaia Magnitude', 'Planet Radius [Earth Radius]', 
                                    'Stellar Radius [Solar Radius]']]
sns.heatmap(kepler_discovery.corr(method='pearson', numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
k_two_discovery = k_two_filtered[['Planet Name', 'Host Name', 'Number of Stars', 'Number of Planets', 'Discovery Method', 
                                   'Discovery Year', 'Discovery Method Encoded', 'Orbital Period [days]',
                                   'Insolation Flux [Earth Flux]', 'Gaia Magnitude', 'Planet Radius [Earth Radius]', 
                                    'Stellar Radius [Solar Radius]']]
sns.heatmap(k_two_discovery.corr(method='pearson', numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### It looks like we are seeing some correlations forming between a handful of columns, which is neat, but lets try running a Principle Component Analysis on all of them to see if there are columns to investigate as a whole rather than manually examining each of them.

# %%
scaler = StandardScaler()


kepler = kepler_filtered.select_dtypes(include=["number"])
k_two = k_two_filtered.select_dtypes(include=["number"])

kepler = kepler.fillna(kepler.median())
k_two = k_two.fillna(k_two.median())

kepler_scaled_data = scaler.fit_transform(kepler)
k_two_scaled_data = scaler.fit_transform(k_two)

pca = PCA(n_components=0.95)
kepler_pc = pca.fit_transform(kepler_scaled_data)
k_two_pc = pca.fit_transform(k_two_scaled_data)

print(kepler_pc)
# Out:
# [[-8.93731128  6.09254598 13.49573573 ... -5.14717434  4.01699451
#    2.65489146]
#  [-2.03916587 -1.21606618 10.3533264  ...  6.71950173  7.72189402
#    1.38011753]
#  [-4.5272699  11.26377264  4.356724   ... -5.888565    0.39514246
#    1.72155508]
#  ...
#  [-1.57737905 -1.49020894 -0.4879368  ... -0.09057621 -0.11360469
#   -1.19633482]
#  [-1.71930904 -1.52023096  1.76876667 ... -1.19348227 -1.12711392
#   -1.41009584]
#  [-1.24256166 -2.25193264  5.05239423 ... -0.79841326 -1.28284139
#   -1.60502057]]

# %%
explained_variance_ratio = pca.explained_variance_ratio_

cumulative_variance = explained_variance_ratio.cumsum()
n_components = next(i for i, total in enumerate(cumulative_variance) if total >= 0.95) + 1  # 95% variance

print(f"Number of components explaining 95% variance: {n_components}")

important_features_kepler = pd.DataFrame(pca.components_, columns=kepler.columns)
important_features_k_two = pd.DataFrame(pca.components_, columns=k_two.columns)
top_features_kepler = {}
top_features_k_two = {}

for i in range(n_components):
    sorted_features_kepler = important_features_kepler.iloc[i].abs().sort_values(ascending=False)
    sorted_features_k_two = important_features_k_two.iloc[i].abs().sort_values(ascending=False)
    top_features_kepler[f"PC{i+1}"] = sorted_features_kepler.index[:10] 
    top_features_k_two[f"PC{i+1}"] = sorted_features_k_two.index[:10] 


print(f'Kepler Principle Components')
for pc, features in top_features_kepler.items():
    print(f"{pc}: {list(features)}")

print(f'\n\nK Two Principle Components')

for pc, features in top_features_k_two.items():
    print(f"{pc}: {list(features)}")
# Out:
# Number of components explaining 95% variance: 16
# Kepler Principle Components
# PC1: ['Stellar Radius [Solar Radius]', 'Stellar Surface Gravity [log10(cm/s**2)]', 'Stellar Mass [Solar mass]', 'Stellar Effective Temperature [K]', 'V (Johnson) Magnitude', 'Gaia Magnitude', 'Planet Radius [Jupiter Radius]', 'Planet Radius [Earth Radius]', 'Distance [pc]', 'Equilibrium Temperature [K]']
# PC2: ['Orbit Semi-Major Axis [au]', 'Orbital Period [days]', 'Discovery Method Encoded', 'Distance [pc]', 'Gaia Magnitude', 'V (Johnson) Magnitude', 'Ks (2MASS) Magnitude', 'Planet Mass or Mass*sin(i) [Jupiter Mass]', 'Planet Mass or Mass*sin(i) [Earth Mass]', 'Stellar Mass [Solar mass]']
# PC3: ['Ks (2MASS) Magnitude', 'Gaia Magnitude', 'Planet Radius [Earth Radius]', 'Planet Radius [Jupiter Radius]', 'V (Johnson) Magnitude', 'Orbital Period [days]', 'Orbit Semi-Major Axis [au]', 'Discovery Method Encoded', 'Number of Planets', 'Stellar Metallicity [dex]']
# PC4: ['Planet Mass or Mass*sin(i) [Jupiter Mass]', 'Planet Mass or Mass*sin(i) [Earth Mass]', 'Distance [pc]', 'Planet Radius [Jupiter Radius]', 'Planet Radius [Earth Radius]', 'Number of Stars', 'Stellar Effective Temperature [K]', 'Discovery Method Encoded', 'Dec [deg]', 'RA [deg]']
# PC5: ['RA [deg]', 'Dec [deg]', 'Planet Mass or Mass*sin(i) [Earth Mass]', 'Planet Mass or Mass*sin(i) [Jupiter Mass]', 'Discovery Method Encoded', 'Discovery Year', 'Eccentricity', 'Number of Planets', 'Orbital Period [days]', 'V (Johnson) Magnitude']
# PC6: ['Data show Transit Timing Variations', 'Discovery Year', 'Planet Mass or Mass*sin(i) [Earth Mass]', 'Planet Mass or Mass*sin(i) [Jupiter Mass]', 'Default Parameter Set', 'Insolation Flux [Earth Flux]', 'Equilibrium Temperature [K]', 'Number of Stars', 'Planet Radius [Earth Radius]', 'Planet Radius [Jupiter Radius]']
# PC7: ['Insolation Flux [Earth Flux]', 'Equilibrium Temperature [K]', 'Discovery Year', 'Discovery Method Encoded', 'Stellar Surface Gravity [log10(cm/s**2)]', 'Stellar Radius [Solar Radius]', 'Default Parameter Set', 'Stellar Mass [Solar mass]', 'Eccentricity', 'Stellar Effective Temperature [K]']
# PC8: ['Eccentricity', 'Default Parameter Set', 'Number of Stars', 'Discovery Year', 'Planet Radius [Jupiter Radius]', 'Planet Radius [Earth Radius]', 'Data show Transit Timing Variations', 'Stellar Metallicity [dex]', 'Stellar Effective Temperature [K]', 'Stellar Mass [Solar mass]']
# PC9: ['Number of Planets', 'Default Parameter Set', 'Data show Transit Timing Variations', 'Discovery Year', 'Number of Stars', 'Stellar Metallicity [dex]', 'Ks (2MASS) Magnitude', 'Stellar Mass [Solar mass]', 'Stellar Effective Temperature [K]', 'Planet Radius [Earth Radius]']
# PC10: ['Eccentricity', 'Stellar Metallicity [dex]', 'Discovery Year', 'Planet Radius [Jupiter Radius]', 'Planet Radius [Earth Radius]', 'Data show Transit Timing Variations', 'Number of Stars', 'Stellar Surface Gravity [log10(cm/s**2)]', 'Stellar Effective Temperature [K]', 'Planet Mass or Mass*sin(i) [Earth Mass]']
# PC11: ['Number of Stars', 'Default Parameter Set', 'Data show Transit Timing Variations', 'Discovery Year', 'Stellar Metallicity [dex]', 'Stellar Mass [Solar mass]', 'Stellar Radius [Solar Radius]', 'Stellar Effective Temperature [K]', 'Planet Radius [Earth Radius]', 'Planet Radius [Jupiter Radius]']
# PC12: ['Data show Transit Timing Variations', 'Default Parameter Set', 'Eccentricity', 'Discovery Year', 'Number of Planets', 'Stellar Metallicity [dex]', 'Insolation Flux [Earth Flux]', 'Stellar Effective Temperature [K]', 'Planet Mass or Mass*sin(i) [Earth Mass]', 'Planet Mass or Mass*sin(i) [Jupiter Mass]']
# PC13: ['Stellar Metallicity [dex]', 'Discovery Year', 'Number of Stars', 'Stellar Surface Gravity [log10(cm/s**2)]', 'Ks (2MASS) Magnitude', 'Planet Radius [Jupiter Radius]', 'Planet Radius [Earth Radius]', 'Number of Planets', 'Eccentricity', 'Stellar Effective Temperature [K]']
# PC14: ['Number of Planets', 'Number of Stars', 'Default Parameter Set', 'Data show Transit Timing Variations', 'Eccentricity', 'Discovery Year', 'Stellar Metallicity [dex]', 'Planet Radius [Jupiter Radius]', 'Planet Radius [Earth Radius]', 'Dec [deg]']
# PC15: ['Stellar Radius [Solar Radius]', 'Stellar Effective Temperature [K]', 'Stellar Surface Gravity [log10(cm/s**2)]', 'Insolation Flux [Earth Flux]', 'Stellar Mass [Solar mass]', 'Equilibrium Temperature [K]', 'Discovery Year', 'Eccentricity', 'Number of Stars', 'Default Parameter Set']
# PC16: ['Equilibrium Temperature [K]', 'Insolation Flux [Earth Flux]', 'Stellar Effective Temperature [K]', 'Stellar Mass [Solar mass]', 'Stellar Radius [Solar Radius]', 'Stellar Surface Gravity [log10(cm/s**2)]', 'Data show Transit Timing Variations', 'Orbit Semi-Major Axis [au]', 'Planet Radius [Jupiter Radius]', 'Planet Radius [Earth Radius]']
#
#
# K Two Principle Components
# PC1: ['Stellar Radius [Solar Radius]', 'Stellar Surface Gravity [log10(cm/s**2)]', 'Stellar Mass [Solar mass]', 'Stellar Effective Temperature [K]', 'V (Johnson) Magnitude', 'Gaia Magnitude', 'Planet Radius [Jupiter Radius]', 'Planet Radius [Earth Radius]', 'Distance [pc]', 'Equilibrium Temperature [K]']
# PC2: ['Orbit Semi-Major Axis [au]', 'Orbital Period [days]', 'Discovery Method Encoded', 'Distance [pc]', 'Gaia Magnitude', 'V (Johnson) Magnitude', 'Ks (2MASS) Magnitude', 'Planet Mass or Mass*sin(i) [Jupiter Mass]', 'Planet Mass or Mass*sin(i) [Earth Mass]', 'Stellar Mass [Solar mass]']
# PC3: ['Ks (2MASS) Magnitude', 'Gaia Magnitude', 'Planet Radius [Earth Radius]', 'Planet Radius [Jupiter Radius]', 'V (Johnson) Magnitude', 'Orbital Period [days]', 'Orbit Semi-Major Axis [au]', 'Discovery Method Encoded', 'Number of Planets', 'Stellar Metallicity [dex]']
# PC4: ['Planet Mass or Mass*sin(i) [Jupiter Mass]', 'Planet Mass or Mass*sin(i) [Earth Mass]', 'Distance [pc]', 'Planet Radius [Jupiter Radius]', 'Planet Radius [Earth Radius]', 'Number of Stars', 'Stellar Effective Temperature [K]', 'Discovery Method Encoded', 'Dec [deg]', 'RA [deg]']
# PC5: ['RA [deg]', 'Dec [deg]', 'Planet Mass or Mass*sin(i) [Earth Mass]', 'Planet Mass or Mass*sin(i) [Jupiter Mass]', 'Discovery Method Encoded', 'Discovery Year', 'Eccentricity', 'Number of Planets', 'Orbital Period [days]', 'V (Johnson) Magnitude']
# PC6: ['Data show Transit Timing Variations', 'Discovery Year', 'Planet Mass or Mass*sin(i) [Earth Mass]', 'Planet Mass or Mass*sin(i) [Jupiter Mass]', 'Default Parameter Set', 'Insolation Flux [Earth Flux]', 'Equilibrium Temperature [K]', 'Number of Stars', 'Planet Radius [Earth Radius]', 'Planet Radius [Jupiter Radius]']
# PC7: ['Insolation Flux [Earth Flux]', 'Equilibrium Temperature [K]', 'Discovery Year', 'Discovery Method Encoded', 'Stellar Surface Gravity [log10(cm/s**2)]', 'Stellar Radius [Solar Radius]', 'Default Parameter Set', 'Stellar Mass [Solar mass]', 'Eccentricity', 'Stellar Effective Temperature [K]']
# PC8: ['Eccentricity', 'Default Parameter Set', 'Number of Stars', 'Discovery Year', 'Planet Radius [Jupiter Radius]', 'Planet Radius [Earth Radius]', 'Data show Transit Timing Variations', 'Stellar Metallicity [dex]', 'Stellar Effective Temperature [K]', 'Stellar Mass [Solar mass]']
# PC9: ['Number of Planets', 'Default Parameter Set', 'Data show Transit Timing Variations', 'Discovery Year', 'Number of Stars', 'Stellar Metallicity [dex]', 'Ks (2MASS) Magnitude', 'Stellar Mass [Solar mass]', 'Stellar Effective Temperature [K]', 'Planet Radius [Earth Radius]']
# PC10: ['Eccentricity', 'Stellar Metallicity [dex]', 'Discovery Year', 'Planet Radius [Jupiter Radius]', 'Planet Radius [Earth Radius]', 'Data show Transit Timing Variations', 'Number of Stars', 'Stellar Surface Gravity [log10(cm/s**2)]', 'Stellar Effective Temperature [K]', 'Planet Mass or Mass*sin(i) [Earth Mass]']
# PC11: ['Number of Stars', 'Default Parameter Set', 'Data show Transit Timing Variations', 'Discovery Year', 'Stellar Metallicity [dex]', 'Stellar Mass [Solar mass]', 'Stellar Radius [Solar Radius]', 'Stellar Effective Temperature [K]', 'Planet Radius [Earth Radius]', 'Planet Radius [Jupiter Radius]']
# PC12: ['Data show Transit Timing Variations', 'Default Parameter Set', 'Eccentricity', 'Discovery Year', 'Number of Planets', 'Stellar Metallicity [dex]', 'Insolation Flux [Earth Flux]', 'Stellar Effective Temperature [K]', 'Planet Mass or Mass*sin(i) [Earth Mass]', 'Planet Mass or Mass*sin(i) [Jupiter Mass]']
# PC13: ['Stellar Metallicity [dex]', 'Discovery Year', 'Number of Stars', 'Stellar Surface Gravity [log10(cm/s**2)]', 'Ks (2MASS) Magnitude', 'Planet Radius [Jupiter Radius]', 'Planet Radius [Earth Radius]', 'Number of Planets', 'Eccentricity', 'Stellar Effective Temperature [K]']
# PC14: ['Number of Planets', 'Number of Stars', 'Default Parameter Set', 'Data show Transit Timing Variations', 'Eccentricity', 'Discovery Year', 'Stellar Metallicity [dex]', 'Planet Radius [Jupiter Radius]', 'Planet Radius [Earth Radius]', 'Dec [deg]']
# PC15: ['Stellar Radius [Solar Radius]', 'Stellar Effective Temperature [K]', 'Stellar Surface Gravity [log10(cm/s**2)]', 'Insolation Flux [Earth Flux]', 'Stellar Mass [Solar mass]', 'Equilibrium Temperature [K]', 'Discovery Year', 'Eccentricity', 'Number of Stars', 'Default Parameter Set']
# PC16: ['Equilibrium Temperature [K]', 'Insolation Flux [Earth Flux]', 'Stellar Effective Temperature [K]', 'Stellar Mass [Solar mass]', 'Stellar Radius [Solar Radius]', 'Stellar Surface Gravity [log10(cm/s**2)]', 'Data show Transit Timing Variations', 'Orbit Semi-Major Axis [au]', 'Planet Radius [Jupiter Radius]', 'Planet Radius [Earth Radius]']

# %%
pc1 = ['Stellar Radius [Solar Radius]', 'Stellar Surface Gravity [log10(cm/s**2)]',
       'Stellar Mass [Solar mass]', 'Stellar Effective Temperature [K]', 
       'V (Johnson) Magnitude', 'Gaia Magnitude', 
       'Planet Radius [Earth Radius]', 'Distance [pc]', 'Equilibrium Temperature [K]']

pc2 = ['Orbit Semi-Major Axis [au]', 'Orbital Period [days]', 
       'Discovery Method Encoded', 'Distance [pc]', 'Gaia Magnitude', 
       'V (Johnson) Magnitude', 'Ks (2MASS) Magnitude',  
       'Planet Mass or Mass*sin(i) [Earth Mass]', 'Stellar Mass [Solar mass]']

pc3 =  ['Ks (2MASS) Magnitude', 'Gaia Magnitude', 
        'Planet Radius [Earth Radius]', 
        'V (Johnson) Magnitude', 'Orbital Period [days]', 
        'Orbit Semi-Major Axis [au]', 'Discovery Method Encoded', 
        'Number of Planets', 'Stellar Metallicity [dex]']


pc1_kepler = kepler[pc1]
pc2_kepler = kepler[pc2]
pc3_kepler = kepler[pc3]

pc1_k_two = k_two[pc1]
pc2_k_two = k_two[pc2]
pc3_k_two = k_two[pc3]

# %%
sns.heatmap(pc1_kepler.corr(method='pearson', numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(pc2_kepler.corr(method='pearson', numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
principle_kepler.head()
# Out:
#       Stellar Radius [Solar Radius]  Stellar Surface Gravity [log10(cm/s**2)]  \
# 47                             0.20                                      5.51
# 48                             0.95                                      4.47
# 5863                           0.95                                      5.35
# 5864                           0.95                                      5.35
# 5865                           0.95                                      5.35
#
#       Distance [pc]  Stellar Mass [Solar mass]  \
# 47          396.332                       0.48
# 48          396.332                       0.48
# 5863       1672.940                       0.96
# 5864       1672.940                       0.96
# 5865       1672.940                       0.96
#
#       Stellar Effective Temperature [K]  Planet Radius [Jupiter Radius]  \
# 47                             29564.00                           0.191
# 48                              5641.07                           0.191
# 5863                           27500.00                           0.191
# 5864                           27500.00                           0.191
# 5865                           27500.00                           0.191
#
#       Planet Radius [Earth Radius]  Planet Mass or Mass*sin(i) [Earth Mass]  \
# 47                           2.141                                591.16084
# 48                           2.141                                603.87700
# 5863                         2.141                                 12.50000
# 5864                         2.141                                 12.50000
# 5865                         2.141                                 12.50000
#
#       Planet Mass or Mass*sin(i) [Jupiter Mass]  Equilibrium Temperature [K]
# 47                                      1.86000                        771.0
# 48                                      1.90000                        771.0
# 5863                                    0.03933                        771.0
# 5864                                    0.03933                        771.0
# 5865                                    0.03933                        771.0
